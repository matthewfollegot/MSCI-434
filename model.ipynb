# %% [markdown]
# ## Assignment 1

# %% [markdown]
# ### Step 1: Import Gurobi

# %%
import gurobipy as gp
from gurobipy import GRB
import random
import csv
import pprint

# %%
warehouses = {
    0:  "thunder bay",
    1:  "sudbury",
    2:  "ottawa",
    3:  "toronto",
    4:  "kingston",
    5:  "windsor",
    6:  "niagara falls",
    7:  "london"
}

retailers = {
    0:  "vaughan",
    1:  "brampton",
    2:  "toronto",
    3:  "mississauga",
    4:  "kitchener",
    5:  "hamilton",
    6:  "leamington",
    7:  "chatham kent",
    8:  "sarnia",
    9:  "stratford",
    10: "bellville",
    11: "peterborough",
    12: "orillia",
    13: "collingwood",
    14: "oshawa",
    15: "milton",
    16: "brantford",
    17: "st catherines",
    18: "welland",
    19: "woodstock"
}

# 2d array that holds all distances
distances = []

with open ('distances.csv', newline='') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
        distances.append(', '.join(row).split(','))
    del distances[0]
    print(distances)
    print(len(distances))
    
random.seed(20726975) # Matt's student ID
demand = [random.randint(10000,75000) for x in range(len(retailers))]
print(demand)
# Out:
# [['1350', '1365', '1381', '1383', '1448', '1432', '1318', '1340', '1272', '1412', '1549', '1389', '1267', '1312', '1417', '1405', '1465', '1468', '1494', '1421'], ['367', '383', '399', '400', '466', '449', '708', '657', '653', '507', '566', '407', '284', '329', '435', '423', '482', '485', '512', '507'], ['401', '408', '440', '473', '491', '522', '733', '682', '677', '532', '271', '272', '377', '459', '396', '448', '555', '558', '584', '532'], ['44.4', '33.8', '14.6', '27.6', '107', '72.2', '346', '296', '291', '148', '190', '137', '146', '161', '62.8', '64.1', '105', '108', '134', '145'], ['273', '274', '248', '282', '351', '331', '593', '542', '538', '392', '79.8', '176', '307', '390', '204', '308', '364', '366', '393', '392'], ['367', '351', '377', '348', '287', '305', '52.4', '80.7', '156', '262', '544', '488', '468', '423', '417', '319', '271', '357', '384', '232'], ['139', '126', '138', '105', '137', '88.2', '352', '302', '297', '178', '312', '264', '240', '225', '185', '90', '111', '24.2', '28.2', '152'], ['191', '175', '201', '172', '111', '129', '170', '119', '100', '64.6', '368', '312', '292', '231', '241', '143', '94.7', '181', '208', '43.5']]
# 8
# [64428, 62093, 27374, 71836, 74540, 51518, 26287, 30382, 56796, 39756, 51791, 43312, 56933, 21992, 41370, 71247, 47952, 13105, 29367, 48123]

# %%
# Debug Cell

for m in range(len(distances)):
    for n in range(len(distances[0])):
        print(f"{warehouses[m]} -> {retailers[n]}: {distances[m][n]} km" )
# Out:
# thunder bay -> vaughan: 1350 km
# thunder bay -> brampton: 1365 km
# thunder bay -> toronto: 1381 km
# thunder bay -> mississauga: 1383 km
# thunder bay -> kitchener: 1448 km
# thunder bay -> hamilton: 1432 km
# thunder bay -> leamington: 1318 km
# thunder bay -> chatham kent: 1340 km
# thunder bay -> sarnia: 1272 km
# thunder bay -> stratford: 1412 km
# thunder bay -> bellville: 1549 km
# thunder bay -> peterborough: 1389 km
# thunder bay -> orillia: 1267 km
# thunder bay -> collingwood: 1312 km
# thunder bay -> oshawa: 1417 km
# thunder bay -> milton: 1405 km
# thunder bay -> brantford: 1465 km
# thunder bay -> st catherines: 1468 km
# thunder bay -> welland: 1494 km
# thunder bay -> woodstock: 1421 km
# sudbury -> vaughan: 367 km
# sudbury -> brampton: 383 km
# sudbury -> toronto: 399 km
# sudbury -> mississauga: 400 km
# sudbury -> kitchener: 466 km
# sudbury -> hamilton: 449 km
# sudbury -> leamington: 708 km
# sudbury -> chatham kent: 657 km
# sudbury -> sarnia: 653 km
# sudbury -> stratford: 507 km
# sudbury -> bellville: 566 km
# sudbury -> peterborough: 407 km
# sudbury -> orillia: 284 km
# sudbury -> collingwood: 329 km
# sudbury -> oshawa: 435 km
# sudbury -> milton: 423 km
# sudbury -> brantford: 482 km
# sudbury -> st catherines: 485 km
# sudbury -> welland: 512 km
# sudbury -> woodstock: 507 km
# ottawa -> vaughan: 401 km
# ottawa -> brampton: 408 km
# ottawa -> toronto: 440 km
# ottawa -> mississauga: 473 km
# ottawa -> kitchener: 491 km
# ottawa -> hamilton: 522 km
# ottawa -> leamington: 733 km
# ottawa -> chatham kent: 682 km
# ottawa -> sarnia: 677 km
# ottawa -> stratford: 532 km
# ottawa -> bellville: 271 km
# ottawa -> peterborough: 272 km
# ottawa -> orillia: 377 km
# ottawa -> collingwood: 459 km
# ottawa -> oshawa: 396 km
# ottawa -> milton: 448 km
# ottawa -> brantford: 555 km
# ottawa -> st catherines: 558 km
# ottawa -> welland: 584 km
# ottawa -> woodstock: 532 km
# toronto -> vaughan: 44.4 km
# toronto -> brampton: 33.8 km
# toronto -> toronto: 14.6 km
# toronto -> mississauga: 27.6 km
# toronto -> kitchener: 107 km
# toronto -> hamilton: 72.2 km
# toronto -> leamington: 346 km
# toronto -> chatham kent: 296 km
# toronto -> sarnia: 291 km
# toronto -> stratford: 148 km
# toronto -> bellville: 190 km
# toronto -> peterborough: 137 km
# toronto -> orillia: 146 km
# toronto -> collingwood: 161 km
# toronto -> oshawa: 62.8 km
# toronto -> milton: 64.1 km
# toronto -> brantford: 105 km
# toronto -> st catherines: 108 km
# toronto -> welland: 134 km
# toronto -> woodstock: 145 km
# kingston -> vaughan: 273 km
# kingston -> brampton: 274 km
# kingston -> toronto: 248 km
# kingston -> mississauga: 282 km
# kingston -> kitchener: 351 km
# kingston -> hamilton: 331 km
# kingston -> leamington: 593 km
# kingston -> chatham kent: 542 km
# kingston -> sarnia: 538 km
# kingston -> stratford: 392 km
# kingston -> bellville: 79.8 km
# kingston -> peterborough: 176 km
# kingston -> orillia: 307 km
# kingston -> collingwood: 390 km
# kingston -> oshawa: 204 km
# kingston -> milton: 308 km
# kingston -> brantford: 364 km
# kingston -> st catherines: 366 km
# kingston -> welland: 393 km
# kingston -> woodstock: 392 km
# windsor -> vaughan: 367 km
# windsor -> brampton: 351 km
# windsor -> toronto: 377 km
# windsor -> mississauga: 348 km
# windsor -> kitchener: 287 km
# windsor -> hamilton: 305 km
# windsor -> leamington: 52.4 km
# windsor -> chatham kent: 80.7 km
# windsor -> sarnia: 156 km
# windsor -> stratford: 262 km
# windsor -> bellville: 544 km
# windsor -> peterborough: 488 km
# windsor -> orillia: 468 km
# windsor -> collingwood: 423 km
# windsor -> oshawa: 417 km
# windsor -> milton: 319 km
# windsor -> brantford: 271 km
# windsor -> st catherines: 357 km
# windsor -> welland: 384 km
# windsor -> woodstock: 232 km
# niagara falls -> vaughan: 139 km
# niagara falls -> brampton: 126 km
# niagara falls -> toronto: 138 km
# niagara falls -> mississauga: 105 km
# niagara falls -> kitchener: 137 km
# niagara falls -> hamilton: 88.2 km
# niagara falls -> leamington: 352 km
# niagara falls -> chatham kent: 302 km
# niagara falls -> sarnia: 297 km
# niagara falls -> stratford: 178 km
# niagara falls -> bellville: 312 km
# niagara falls -> peterborough: 264 km
# niagara falls -> orillia: 240 km
# niagara falls -> collingwood: 225 km
# niagara falls -> oshawa: 185 km
# niagara falls -> milton: 90 km
# niagara falls -> brantford: 111 km
# niagara falls -> st catherines: 24.2 km
# niagara falls -> welland: 28.2 km
# niagara falls -> woodstock: 152 km
# london -> vaughan: 191 km
# london -> brampton: 175 km
# london -> toronto: 201 km
# london -> mississauga: 172 km
# london -> kitchener: 111 km
# london -> hamilton: 129 km
# london -> leamington: 170 km
# london -> chatham kent: 119 km
# london -> sarnia: 100 km
# london -> stratford: 64.6 km
# london -> bellville: 368 km
# london -> peterborough: 312 km
# london -> orillia: 292 km
# london -> collingwood: 231 km
# london -> oshawa: 241 km
# london -> milton: 143 km
# london -> brantford: 94.7 km
# london -> st catherines: 181 km
# london -> welland: 208 km
# london -> woodstock: 43.5 km
